# %%
#importing the required librraries

import cv2 as cv
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
#trying on something simpler first .
#then implimenting on image of the classroom

# %%
#reading the image 
img=cv.imread('TS3.jpg',cv.IMREAD_GRAYSCALE)

# %%
#printing the image
plt.imshow(img,cmap='gray',interpolation='bicubic')
